# %%
# import packages
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# print out versions of packages installed
# check that the match the package version from requirements.txt
print('Pandas version:')
print('Numpy version:')
# Out:
# Pandas version:
# Numpy version:

# %%
# load csv file with pandas from path
data_dir = 'data'
filename = 'aarhusbolig.csv'
data_path = os.path.join(data_dir, filename)
df = pd.read_csv(data_path)

# %% [markdown]
# Perform a task from the past weeks lectures.
#
# Ideas:
# - Data visualization
# - RegEx cleaning or validation

# %%
df.head()
# Out:
#    listingid  companyid    company  price  \
# 0       4023         31  bk-aarhus   6897
# 1       3003         31  bk-aarhus   7642
# 2         34         31  bk-aarhus   8304
# 3         14         31  bk-aarhus   7619
# 4        258         31  bk-aarhus   3119
#
#                                                  url       long        lat  \
# 0  https://aarhusbolig.dk/afdelinger/?bolignr=402...  56.167299  10.189047
# 1  https://aarhusbolig.dk/afdelinger/?bolignr=300...  56.167299  10.189047
# 2  https://aarhusbolig.dk/afdelinger/?bolignr=34&...  56.178432  10.195098
# 3  https://aarhusbolig.dk/afdelinger/?bolignr=14&...  56.178432  10.195098
# 4  https://aarhusbolig.dk/afdelinger/?bolignr=258...  56.167897  10.184841
#
#                                           address       type  rooms  ...  \
# 0  Afd. 1  Paludan Müllers Vej/Jens Baggesens Vej  Lejlighed      2  ...
# 1  Afd. 1  Paludan Müllers Vej/Jens Baggesens Vej  Lejlighed      3  ...
# 2                      Afd. 2 Haugesundsvej m.fl.   Rækkehus      3  ...
# 3                      Afd. 2 Haugesundsvej m.fl.   Rækkehus      4  ...
# 4                   Afd. 3 Viggo Stuckenbergs Vej  Lejlighed      1  ...
#
#    listings                                               text  deposit  \
# 0     201.0  Husdyr: Det er tilladt af have en lille hund (...  10600.0
# 1      75.0  Husdyr: Det er tilladt af have en lille hund (...  11100.0
# 2       2.0  Husdyr: Det er tilladt at holde husdyr.Udgifte...  25000.0
# 3      34.0  Husdyr: Det er tilladt at holde husdyr.Udgifte...  25000.0
# 4      15.0  Husdyr: Det er tilladt at holde højest 2 neutr...   3920.0
#
#      rent  electricity   heat  water  tv_internet  b-ordning         other
# 0  5366.0          NaN  691.0  200.0        205.0        NaN   7671.356346
# 1  5790.0          NaN  795.0  219.0        205.0        NaN   8496.356346
# 2  6033.0          NaN    NaN    NaN        450.0        NaN  10298.373530
# 3  6033.0          NaN    NaN    NaN          NaN        NaN   9411.373530
# 4  1915.0          NaN  241.0   83.0          NaN        NaN   4109.352738
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2116 entries, 0 to 2115
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   listingid    2116 non-null   int64
#  1   companyid    2116 non-null   int64
#  2   company      2116 non-null   object
#  3   price        2116 non-null   int64
#  4   url          2116 non-null   object
#  5   long         2108 non-null   float64
#  6   lat          2108 non-null   float64
#  7   address      2116 non-null   object
#  8   type         2116 non-null   object
#  9   rooms        2116 non-null   int64
#  10  size_m2      2116 non-null   int64
#  11  listings     2111 non-null   float64
#  12  text         2114 non-null   object
#  13  deposit      2112 non-null   float64
#  14  rent         2116 non-null   float64
#  15  electricity  338 non-null    float64
#  16  heat         1146 non-null   float64
#  17  water        1368 non-null   float64
#  18  tv_internet  512 non-null    float64
#  19  b-ordning    127 non-null    float64
#  20  other        2116 non-null   float64
# dtypes: float64(11), int64(5), object(5)
# memory usage: 347.3+ KB

# %%
df['company'].nunique()
# Out:
# 12

# %% [markdown]
# ## Cleaning

# %%
# Drop specified columns
df = df.drop(columns=['b-ordning','address', 'url', 'text'])

# %%
df.head()
# Out:
#    listingid  companyid    company  price       long        lat       type  \
# 0       4023         31  bk-aarhus   6897  56.167299  10.189047  Lejlighed
# 1       3003         31  bk-aarhus   7642  56.167299  10.189047  Lejlighed
# 2         34         31  bk-aarhus   8304  56.178432  10.195098   Rækkehus
# 3         14         31  bk-aarhus   7619  56.178432  10.195098   Rækkehus
# 4        258         31  bk-aarhus   3119  56.167897  10.184841  Lejlighed
#
#    rooms  size_m2  listings  deposit    rent  electricity   heat  water  \
# 0      2       70     201.0  10600.0  5366.0          NaN  691.0  200.0
# 1      3       77      75.0  11100.0  5790.0          NaN  795.0  219.0
# 2      3      102       2.0  25000.0  6033.0          NaN    NaN    NaN
# 3      4      102      34.0  25000.0  6033.0          NaN    NaN    NaN
# 4      1       28      15.0   3920.0  1915.0          NaN  241.0   83.0
#
#    tv_internet         other
# 0        205.0   7671.356346
# 1        205.0   8496.356346
# 2        450.0  10298.373530
# 3          NaN   9411.373530
# 4          NaN   4109.352738

# %%
# Plotting the histogram
plt.hist(df['rooms'], bins=5, color='skyblue', edgecolor='black')

# Adding labels and title
plt.xlabel('Numbers of rooms')
plt.ylabel('Frequency')
plt.title('Distribution of rooms')

# Display the plot
plt.show()
